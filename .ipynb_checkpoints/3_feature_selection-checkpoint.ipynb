# %% [markdown]
# # Features selection

# %%
# Author: Soumya Sambeet Mohapatra
# Date: 03-05-2022
# Description: Code to select most relevant features using Heatmap of Correlation matrix

# %% [markdown]
# * This notebook contains code for selection of important features from the dataset.
# * The important features are selected and filtered from the dataset and stored in a new file.
# * The definitions of the selected features are provided below for reference.

# %% [markdown]
# ## Importing modules

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Loading data from CSV file

# %%
df = pd.read_csv('data/genre_data_clean.csv')
df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.507  0.7100    5    -5.020     1       0.0291        0.0975
# 1         0.496  0.3780   11    -7.878     1       0.0336        0.8980
# 2         0.760  0.7650    0    -9.319     1       0.0352        0.2890
# 3         0.607  0.1960    1   -19.705     1       0.0595        0.9040
# 4         0.497  0.0919    3   -15.685     1       0.0704        0.9680
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000011     0.170    0.450  134.647  audio_features
# 1          0.000001     0.109    0.335  144.092  audio_features
# 2          0.000008     0.233    0.868  107.602  audio_features
# 3          0.727000     0.111    0.187  111.031  audio_features
# 4          0.002140     0.133    0.548  206.431  audio_features
#
#                        id                                   uri  \
# 0  14J3PO0VnhtcRa31r7Aj1L  spotify:track:14J3PO0VnhtcRa31r7Aj1L
# 1  2SZDu4esDLUISRnpYQE17b  spotify:track:2SZDu4esDLUISRnpYQE17b
# 2  5E2EpolcGmcbYpsv0z6jAZ  spotify:track:5E2EpolcGmcbYpsv0z6jAZ
# 3  5RVEXH7OR9rcRz7eeviOzc  spotify:track:5RVEXH7OR9rcRz7eeviOzc
# 4  7CNaYAdLyi86kofGafReiT  spotify:track:7CNaYAdLyi86kofGafReiT
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/14J3PO0Vnhtc...
# 1  https://api.spotify.com/v1/tracks/2SZDu4esDLUI...
# 2  https://api.spotify.com/v1/tracks/5E2EpolcGmcb...
# 3  https://api.spotify.com/v1/tracks/5RVEXH7OR9rc...
# 4  https://api.spotify.com/v1/tracks/7CNaYAdLyi86...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/14J3...       273573
# 1  https://api.spotify.com/v1/audio-analysis/2SZD...       277667
# 2  https://api.spotify.com/v1/audio-analysis/5E2E...       226933
# 3  https://api.spotify.com/v1/audio-analysis/5RVE...       223948
# 4  https://api.spotify.com/v1/audio-analysis/7CNa...       139693
#
#    time_signature  year     genre
# 0               4  1999  acoustic
# 1               3  1999  acoustic
# 2               4  1999  acoustic
# 3               4  1999  acoustic
# 4               4  1999  acoustic

# %% [markdown]
# ## Removing unnecessary features

# %% [markdown]
# There are 21 columns in the dataset. Below is a list of all the columns.

# %%
df.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature', 'year', 'genre'],
#       dtype='object')

# %% [markdown]
# It can be identified that the following columns have no significance in training a machine learning mode:
#
# 1. `type`
# 2. `id`
# 3. `uri`
# 4. `track_href`
# 5. `analysis_url`
# 6. `year`
#
# Therefore, these columns are dropped from the dataset.

# %%
df.drop(
    ['type', 'id', 'uri', 'track_href', 'analysis_url', 'year'], 
    axis=1, 
    inplace=True
) 
df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.507  0.7100    5    -5.020     1       0.0291        0.0975
# 1         0.496  0.3780   11    -7.878     1       0.0336        0.8980
# 2         0.760  0.7650    0    -9.319     1       0.0352        0.2890
# 3         0.607  0.1960    1   -19.705     1       0.0595        0.9040
# 4         0.497  0.0919    3   -15.685     1       0.0704        0.9680
#
#    instrumentalness  liveness  valence    tempo  duration_ms  time_signature  \
# 0          0.000011     0.170    0.450  134.647       273573               4
# 1          0.000001     0.109    0.335  144.092       277667               3
# 2          0.000008     0.233    0.868  107.602       226933               4
# 3          0.727000     0.111    0.187  111.031       223948               4
# 4          0.002140     0.133    0.548  206.431       139693               4
#
#       genre
# 0  acoustic
# 1  acoustic
# 2  acoustic
# 3  acoustic
# 4  acoustic

# %% [markdown]
# ## Correlation Matrix

# %% [markdown]
# It can be shown that some features are more uncorrelated with the dataset in comparison to others.

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above correlation matrix, it can be seen that the features `key`, `mode`, `liveness`, and `duration_ms` have nearly 0 correlation. The features `mode`, and `liveliness` do not have much impact on the genre of the music. However, these features can be used for further statistical analysis. Therefore to further reduce the features from our dataset, we remove `key`, and `duration_ms`.

# %%
df.drop(['key', 'duration_ms'], axis=1, inplace=True)

# %% [markdown]
# ## Scatter Matrix

# %%
from pandas.plotting import scatter_matrix
attributes = ['danceability', 'energy', 'loudness', 'speechiness',
       'acousticness', 'instrumentalness', 'valence', 'tempo',
    'time_signature', 'genre']
scatter_matrix(df,figsize=(12,8))
# Out:
# array([[<AxesSubplot:xlabel='danceability', ylabel='danceability'>,
#         <AxesSubplot:xlabel='energy', ylabel='danceability'>,
#         <AxesSubplot:xlabel='loudness', ylabel='danceability'>,
#         <AxesSubplot:xlabel='mode', ylabel='danceability'>,
#         <AxesSubplot:xlabel='speechiness', ylabel='danceability'>,
#         <AxesSubplot:xlabel='acousticness', ylabel='danceability'>,
#         <AxesSubplot:xlabel='instrumentalness', ylabel='danceability'>,
#         <AxesSubplot:xlabel='liveness', ylabel='danceability'>,
#         <AxesSubplot:xlabel='valence', ylabel='danceability'>,
#         <AxesSubplot:xlabel='tempo', ylabel='danceability'>,
#         <AxesSubplot:xlabel='time_signature', ylabel='danceability'>],
#        [<AxesSubplot:xlabel='danceability', ylabel='energy'>,
#         <AxesSubplot:xlabel='energy', ylabel='energy'>,
#         <AxesSubplot:xlabel='loudness', ylabel='energy'>,
#         <AxesSubplot:xlabel='mode', ylabel='energy'>,
#         <AxesSubplot:xlabel='speechiness', ylabel='energy'>,
#         <AxesSubplot:xlabel='acousticness', ylabel='energy'>,
#         <AxesSubplot:xlabel='instrumentalness', ylabel='energy'>,
#         <AxesSubplot:xlabel='liveness', ylabel='energy'>,
#         <AxesSubplot:xlabel='valence', ylabel='energy'>,
#         <AxesSubplot:xlabel='tempo', ylabel='energy'>,
#         <AxesSubplot:xlabel='time_signature', ylabel='energy'>],
#        [<AxesSubplot:xlabel='danceability', ylabel='loudness'>,
#         <AxesSubplot:xlabel='energy', ylabel='loudness'>,
#         <AxesSubplot:xlabel='loudness', ylabel='loudness'>,
#         <AxesSubplot:xlabel='mode', ylabel='loudness'>,
#         <AxesSubplot:xlabel='speechiness', ylabel='loudness'>,
#         <AxesSubplot:xlabel='acousticness', ylabel='loudness'>,
#         <AxesSubplot:xlabel='instrumentalness', ylabel='loudness'>,
#         <AxesSubplot:xlabel='liveness', ylabel='loudness'>,
#         <AxesSubplot:xlabel='valence', ylabel='loudness'>,
#         <AxesSubplot:xlabel='tempo', ylabel='loudness'>,
#         <AxesSubplot:xlabel='time_signature', ylabel='loudness'>],
#        [<AxesSubplot:xlabel='danceability', ylabel='mode'>,
#         <AxesSubplot:xlabel='energy', ylabel='mode'>,
#         <AxesSubplot:xlabel='loudness', ylabel='mode'>,
#         <AxesSubplot:xlabel='mode', ylabel='mode'>,
#         <AxesSubplot:xlabel='speechiness', ylabel='mode'>,
#         <AxesSubplot:xlabel='acousticness', ylabel='mode'>,
#         <AxesSubplot:xlabel='instrumentalness', ylabel='mode'>,
#         <AxesSubplot:xlabel='liveness', ylabel='mode'>,
#         <AxesSubplot:xlabel='valence', ylabel='mode'>,
#         <AxesSubplot:xlabel='tempo', ylabel='mode'>,
#         <AxesSubplot:xlabel='time_signature', ylabel='mode'>],
#        [<AxesSubplot:xlabel='danceability', ylabel='speechiness'>,
#         <AxesSubplot:xlabel='energy', ylabel='speechiness'>,
#         <AxesSubplot:xlabel='loudness', ylabel='speechiness'>,
#         <AxesSubplot:xlabel='mode', ylabel='speechiness'>,
#         <AxesSubplot:xlabel='speechiness', ylabel='speechiness'>,
#         <AxesSubplot:xlabel='acousticness', ylabel='speechiness'>,
#         <AxesSubplot:xlabel='instrumentalness', ylabel='speechiness'>,
#         <AxesSubplot:xlabel='liveness', ylabel='speechiness'>,
#         <AxesSubplot:xlabel='valence', ylabel='speechiness'>,
#         <AxesSubplot:xlabel='tempo', ylabel='speechiness'>,
#         <AxesSubplot:xlabel='time_signature', ylabel='speechiness'>],
#        [<AxesSubplot:xlabel='danceability', ylabel='acousticness'>,
#         <AxesSubplot:xlabel='energy', ylabel='acousticness'>,
#         <AxesSubplot:xlabel='loudness', ylabel='acousticness'>,
#         <AxesSubplot:xlabel='mode', ylabel='acousticness'>,
#         <AxesSubplot:xlabel='speechiness', ylabel='acousticness'>,
#         <AxesSubplot:xlabel='acousticness', ylabel='acousticness'>,
#         <AxesSubplot:xlabel='instrumentalness', ylabel='acousticness'>,
#         <AxesSubplot:xlabel='liveness', ylabel='acousticness'>,
#         <AxesSubplot:xlabel='valence', ylabel='acousticness'>,
#         <AxesSubplot:xlabel='tempo', ylabel='acousticness'>,
#         <AxesSubplot:xlabel='time_signature', ylabel='acousticness'>],
#        [<AxesSubplot:xlabel='danceability', ylabel='instrumentalness'>,
#         <AxesSubplot:xlabel='energy', ylabel='instrumentalness'>,
#         <AxesSubplot:xlabel='loudness', ylabel='instrumentalness'>,
#         <AxesSubplot:xlabel='mode', ylabel='instrumentalness'>,
#         <AxesSubplot:xlabel='speechiness', ylabel='instrumentalness'>,
#         <AxesSubplot:xlabel='acousticness', ylabel='instrumentalness'>,
#         <AxesSubplot:xlabel='instrumentalness', ylabel='instrumentalness'>,
#         <AxesSubplot:xlabel='liveness', ylabel='instrumentalness'>,
#         <AxesSubplot:xlabel='valence', ylabel='instrumentalness'>,
#         <AxesSubplot:xlabel='tempo', ylabel='instrumentalness'>,
#         <AxesSubplot:xlabel='time_signature', ylabel='instrumentalness'>],
#        [<AxesSubplot:xlabel='danceability', ylabel='liveness'>,
#         <AxesSubplot:xlabel='energy', ylabel='liveness'>,
#         <AxesSubplot:xlabel='loudness', ylabel='liveness'>,
#         <AxesSubplot:xlabel='mode', ylabel='liveness'>,
#         <AxesSubplot:xlabel='speechiness', ylabel='liveness'>,
#         <AxesSubplot:xlabel='acousticness', ylabel='liveness'>,
#         <AxesSubplot:xlabel='instrumentalness', ylabel='liveness'>,
#         <AxesSubplot:xlabel='liveness', ylabel='liveness'>,
#         <AxesSubplot:xlabel='valence', ylabel='liveness'>,
#         <AxesSubplot:xlabel='tempo', ylabel='liveness'>,
#         <AxesSubplot:xlabel='time_signature', ylabel='liveness'>],
#        [<AxesSubplot:xlabel='danceability', ylabel='valence'>,
#         <AxesSubplot:xlabel='energy', ylabel='valence'>,
#         <AxesSubplot:xlabel='loudness', ylabel='valence'>,
#         <AxesSubplot:xlabel='mode', ylabel='valence'>,
#         <AxesSubplot:xlabel='speechiness', ylabel='valence'>,
#         <AxesSubplot:xlabel='acousticness', ylabel='valence'>,
#         <AxesSubplot:xlabel='instrumentalness', ylabel='valence'>,
#         <AxesSubplot:xlabel='liveness', ylabel='valence'>,
#         <AxesSubplot:xlabel='valence', ylabel='valence'>,
#         <AxesSubplot:xlabel='tempo', ylabel='valence'>,
#         <AxesSubplot:xlabel='time_signature', ylabel='valence'>],
#        [<AxesSubplot:xlabel='danceability', ylabel='tempo'>,
#         <AxesSubplot:xlabel='energy', ylabel='tempo'>,
#         <AxesSubplot:xlabel='loudness', ylabel='tempo'>,
#         <AxesSubplot:xlabel='mode', ylabel='tempo'>,
#         <AxesSubplot:xlabel='speechiness', ylabel='tempo'>,
#         <AxesSubplot:xlabel='acousticness', ylabel='tempo'>,
#         <AxesSubplot:xlabel='instrumentalness', ylabel='tempo'>,
#         <AxesSubplot:xlabel='liveness', ylabel='tempo'>,
#         <AxesSubplot:xlabel='valence', ylabel='tempo'>,
#         <AxesSubplot:xlabel='tempo', ylabel='tempo'>,
#         <AxesSubplot:xlabel='time_signature', ylabel='tempo'>],
#        [<AxesSubplot:xlabel='danceability', ylabel='time_signature'>,
#         <AxesSubplot:xlabel='energy', ylabel='time_signature'>,
#         <AxesSubplot:xlabel='loudness', ylabel='time_signature'>,
#         <AxesSubplot:xlabel='mode', ylabel='time_signature'>,
#         <AxesSubplot:xlabel='speechiness', ylabel='time_signature'>,
#         <AxesSubplot:xlabel='acousticness', ylabel='time_signature'>,
#         <AxesSubplot:xlabel='instrumentalness', ylabel='time_signature'>,
#         <AxesSubplot:xlabel='liveness', ylabel='time_signature'>,
#         <AxesSubplot:xlabel='valence', ylabel='time_signature'>,
#         <AxesSubplot:xlabel='tempo', ylabel='time_signature'>,
#         <AxesSubplot:xlabel='time_signature', ylabel='time_signature'>]],
#       dtype=object)

# %% [markdown]
# ## Writing filtered dataset to file

# %%
df.to_csv('data/genre_data_final.csv', index=False)
